# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("../../data/all_articles5-v2.csv")
        
df = df.rename(columns={
    "full_text": "article",
    "abstract": "abstract"
})
df = df.dropna(subset=["article", "abstract"])
df = df[df["article"].str.strip().astype(bool)]
df = df[df["abstract"].str.strip().astype(bool)]
df["article"] = df["article"].astype(str)
df["abstract"] = df["abstract"].astype(str)

# %%
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# %%
import ast
test_df['section_names'] = test_df['section_names'].apply(ast.literal_eval)
test_df['sections'] = test_df['sections'].apply(ast.literal_eval)

# %%
import re

def distribute_paragraphs_to_six_facets(text):
    facets = [""] * 6
    if not isinstance(text, str) or not text.strip():
        return facets
    
    paragraphs = [p.strip() for p in re.split(r'\n\s*\n', text.strip()) if p.strip()]
    # print(f"Total paragraphs: {len(paragraphs)}")
    if not paragraphs:
        return facets
    
    total_len = sum(len(p) for p in paragraphs)
    cutoffs = [(total_len * i) // 6 for i in range(1, 6)]
    
    current_facet_idx = 0
    cumulative_len = 0
    facet_contents = [[] for _ in range(6)]
    
    for p in paragraphs:
        p_len = len(p.strip())
        if current_facet_idx < 5 and cumulative_len >= cutoffs[current_facet_idx] and facet_contents[current_facet_idx]:
            current_facet_idx += 1
            
        facet_contents[current_facet_idx].append(p.strip())
        cumulative_len += p_len
    
    for i in range(6):
        facets[i] = "\n\n".join(facet_contents[i])
        
    return facets

# %%
import numpy as np
def clean_for_json(data_dict):
    cleaned = {}
    for k, v in data_dict.items():
        if pd.isna(v): # 如果是 NaN 或 None
            cleaned[k] = "" # 轉成空字串
        elif isinstance(v, (np.int64, np.int32)): # 修正 numpy int 問題
            cleaned[k] = int(v)
        elif isinstance(v, (np.float64, np.float32)): # 修正 numpy float 問題
            cleaned[k] = float(v)
        else:
            cleaned[k] = v
    return cleaned

# %%
total_rows = len(test_df)

# %%
import json
output_file = "../dataset/simple_split_stream.jsonl"
for index, row in test_df.iterrows():
    # print(len(row['sections']))
    six_facets = distribute_paragraphs_to_six_facets('\n\n'.join(row['sections']))
    dict_row = {
        "first_facet": six_facets[0].strip() if six_facets[0].strip() else "",
        "second_facet": six_facets[1].strip() if six_facets[1].strip() else "",
        "third_facet": six_facets[2].strip() if six_facets[2].strip() else "",
        "fourth_facet": six_facets[3].strip() if six_facets[3].strip() else "",
        "fifth_facet": six_facets[4].strip() if six_facets[4].strip() else "",
        "sixth_facet": six_facets[5].strip() if six_facets[5].strip() else "",
    }
    
    save_data = row.to_dict()
    del save_data['sections']      
    del save_data['section_names']
    save_data.update(dict_row)
    lean_data = clean_for_json(save_data)
    clean_data = clean_for_json(save_data)
    with open(output_file, 'a', encoding='utf-8') as f_out:
        json.dump(clean_data, f_out, ensure_ascii=False)
        f_out.write('\n') 
        f_out.flush() 
    
    if (index + 1) % 10 == 0:
        print(f"Processed {index + 1}/{total_rows} rows...")
# Out:
# Processed 38490/4631 rows...
# Processed 11570/4631 rows...
# Processed 21670/4631 rows...
# Processed 28360/4631 rows...
# Processed 68400/4631 rows...
# Processed 55450/4631 rows...
# Processed 64880/4631 rows...
# Processed 64270/4631 rows...
# Processed 29900/4631 rows...
# Processed 33380/4631 rows...
# Processed 1010/4631 rows...
# Processed 70510/4631 rows...
# Processed 68940/4631 rows...
# Processed 57960/4631 rows...
# Processed 2070/4631 rows...
# Processed 44830/4631 rows...
# Processed 24650/4631 rows...
# Processed 35070/4631 rows...
# Processed 14390/4631 rows...
# Processed 67580/4631 rows...
# Processed 62530/4631 rows...
# Processed 27180/4631 rows...
# Processed 38140/4631 rows...
# Processed 30490/4631 rows...
# Processed 63660/4631 rows...
# Processed 62600/4631 rows...
# Processed 26620/4631 rows...
# Processed 8070/4631 rows...
# Processed 4480/4631 rows...
# Processed 33510/4631 rows...
# Processed 50050/4631 rows...
# Processed 29830/4631 rows...
# Processed 23560/4631 rows...
# Processed 23440/4631 rows...
# Processed 7780/4631 rows...
# Processed 54790/4631 rows...
# Processed 55200/4631 rows...
# Processed 38240/4631 rows...
# Processed 24300/4631 rows...
# Processed 6650/4631 rows...
# Processed 66320/4631 rows...
# Processed 61990/4631 rows...
# Processed 3340/4631 rows...
# Processed 57140/4631 rows...
# Processed 47140/4631 rows...
# Processed 62160/4631 rows...
# Processed 6140/4631 rows...
# Processed 58210/4631 rows...
# Processed 2500/4631 rows...
# Processed 23330/4631 rows...
# Processed 64000/4631 rows...
# Processed 63940/4631 rows...
# Processed 15080/4631 rows...
# Processed 46620/4631 rows...
# Processed 20420/4631 rows...
# Processed 44500/4631 rows...
# Processed 26500/4631 rows...
# Processed 26670/4631 rows...
# Processed 48130/4631 rows...
# Processed 5640/4631 rows...
# Processed 17950/4631 rows...

# %%
import pandas as pd
df = pd.read_json("../dataset/simple_split_stream.jsonl", lines=True)
df
# Out:
#      article_id      pmid                                              title  \
# 0     PMC696377  31842374  Plasmodesmata Conductivity Regulation: A Mecha...
# 1     PMC958938  36324544  Abderrazak Hajjioui: shining a light on rehabi...
# 2     PMC561342  28970690  Successful surgical procedure in a patient of ...
# 3     PMC642025  30875402  Assessment of early goal-directed therapy guid...
# 4     PMC579575  29172801  The new European guideline on cardiovascular d...
# ...         ...       ...                                                ...
# 4626  PMC883360  35158828  Alternative Splicing, Epigenetic Modifications...
# 4627  PMC424766  25403234  Let it grow—the open market solution to mariju...
# 4628  PMC766392  33167486  Gated Dehazing Network via Least Square Advers...
# 4629  PMC436037  21147631  Lung mass in a 28-year-old male: A case report...
# 4630   PMC42858  15157276
#
#                                                abstract  \
# 0     <S> plant cells form a multicellular symplast ...
# 1     <S> abderrazak hajjioui talks to tatum anderso...
# 2     <S> this case marks the beginning of issuing c...
# 3     <S> background\nassessing adherence to early g...
# 4     <S> abstract\nthe new guideline on cardiovascu...
# ...                                                 ...
# 4626  <S> simple summary\nepigenetics studies the al...
# 4627  <S> this commentary evaluates regulatory frame...
# 4628  <S> in a hazy environment, visibility is reduc...
# 4629  <S> a twenty eight-year-old male presented wit...
# 4630  <S> the important role of apoav gene t-1131>c ...
#
#                                                 article missing_fields  \
# 0     due to their immobile lifestyle, plants are ex...             []
# 1     i noticed that moroccan practitioners tended t...             []
# 2     cci may be done at 10 min, 1 h, or 24 h after ...             []
# 3     assessing adherence to early goal-directed the...             []
# 4     in the new guideline , the accessible and simp...             []
# ...                                                 ...            ...
# 4626  epigenetics studies the alteration of gene exp...             []
# 4627  this article presents the case for legalizing ...             []
# 4628  especially, haze reduces the visibility of the...             []
# 4629  it has distinct pathologic features and occurs...             []
# 4630  on the association between the t-1131>c apoav ...      ['title']
#
#                                             first_facet  \
# 0     due to their immobile lifestyle, plants are ex...
# 1     i noticed that moroccan practitioners tended t...
# 2     cci may be done at 10 min, 1 h, or 24 h after ...
# 3     assessing adherence to early goal-directed the...
# 4     in the new guideline , the accessible and simp...
# ...                                                 ...
# 4626  epigenetics studies the alteration of gene exp...
# 4627  this article presents the case for legalizing ...
# 4628  especially, haze reduces the visibility of the...
# 4629  it has distinct pathologic features and occurs...
# 4630  on the association between the t-1131>c apoav ...
#
#                                            second_facet  \
# 0     this group of proteins include non-secreted cy...
# 1
# 2     frequent transfusions were required over the y...
# 3     a panel of five pediatric critical care expert...
# 4     in the new guideline , the accessible and simp...
# ...                                                 ...
# 4626  when these islands are located in gene promote...
# 4627  this article presents the case for legalizing ...
# 4628  a haze image ix acquired by a digital image se...
# 4629  hepatocellular carcinoma is a highly malignant...
# 4630  using a previously described method , we analy...
#
#                                             third_facet  \
# 0     the cytoskeletal proteins actin and myosin hav...
# 1
# 2     when hla antibodies are present, patients may ...
# 3     a panel of five pediatric critical care expert...
# 4     the new guideline acknowledges that especially...
# ...                                                 ...
# 4626  due to the already mentioned coupling with tra...
# 4627  marijuana’s prospective legalization should be...
# 4628  to remove the haze, the proposed generator tak...
# 4629
# 4630  we conclude that the t-1131>c variant in the a...
#
#                                            fourth_facet  \
# 0     reticulons (rtnlb), as family of membrane er-t...
# 1
# 2     this case shows us that, when we are facing a ...
# 3     the 28 components were divided into 18 general...
# 4     organizing broad cvd prevention is still a hug...
# ...                                                 ...
# 4626  since the launching of the encode project in 2...
# 4627  marijuana’s legalization raises numerous criti...
# 4628  the loss function of the proposed method consi...
# 4629
# 4630
#
#                                             fifth_facet  \
# 0     the callose contents at pd depends on the acti...
# 1
# 2
# 3     the 28 components were divided into 18 general...
# 4     to improve the translation of the recommendati...
# ...                                                 ...
# 4626  remodeling of chromatin is often considered as...
# 4627  the current regulatory model for marijuana is ...
# 4628  for example, in an outdoor environment, the de...
# 4629
# 4630
#
#                                             sixth_facet
# 0     in the selection of proteins that bind to pd-l...
# 1
# 2
# 3     adherence determination based on selected clin...
# 4     the new european guideline on cardiovascular d...
# ...                                                 ...
# 4626  in a certain sense, present section covers an ...
# 4627  what is missing from most analyses is recognit...
# 4628  in order to evaluate the qualitative performan...
# 4629
# 4630
#
# [4631 rows x 12 columns]
