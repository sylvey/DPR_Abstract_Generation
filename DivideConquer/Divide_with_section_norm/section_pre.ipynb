# %%
import pandas as pd

df_test = pd.read_csv("../../data/all_articles5-v2.csv")
df_test
# Out:
#       article_id      pmid                                              title  \
# 0      PMC498926  26530308                                            Erratum
# 1      PMC516104  28018390  Emerging Technologies for the Production of Re...
# 2      PMC503397  27721798  Cardiac Troponin and Tropomyosin: Structural a...
# 3      PMC831342  34327328  Corrigendum: A Frequency-Domain Machine Learni...
# 4      PMC878323  35110838  Evolving Techniques in RSI: Can the Choice of ...
# ...          ...       ...                                                ...
# 71915  PMC746268  32130345  2020 Brazilian Thoracic Association recommenda...
# 71916  PMC875428  35082458          Change is Inevitable Progress is Optional
# 71917  PMC343773  22932762  Novel Vectors of Malaria Parasite in the Weste...
# 71918  PMC986711  36677594         Natural Products for Cosmetic Applications
# 71919  PMC553242  28775723   Corrigendum: Dicer-Like Genes Are Required for H
#
#                                                 abstract  \
# 0      <S> lopez de lapuente a, pinto-medel mj, astob...
# 1      <S> plant cell walls are composed predominantl...
# 2      <S> inherited myopathies affect both skeletal ...
# 3                                                    NaN
# 4      <S> how to cite this article: george b, joachi...
# ...                                                  ...
# 71915  <S> abstract\nthe pharmacological management o...
# 71916  <S> how to cite this article: peter j. change ...
# 71917  <S> the main method of malaria control is base...
# 71918                                                NaN
# 71919                                                NaN
#
#                                                full_text  \
# 0      in the above-mentioned article, published in m...
# 1      the demand for chemical energy is projected to...
# 2      cardiomyopathies represent a collection of dis...
# 3      results of a bivariate regression of oef0 agai...
# 4                                                    NaN
# ...                                                  ...
# 71915  the pharmacological management of asthma has c...
# 71916  the most important factor that determined the ...
# 71917  to the editor: the primary malaria control tec...
# 71918  natural products provide an interesting and la...
# 71919  the authors declare that the research was cond...
#
#                                            section_names  \
# 0                                               ['Body']
# 1      ['Introduction', 'Biofuel Feedstocks', 'Engine...
# 2      ['Introduction', 'From code to message', 'The ...
# 3                                               ['Body']
# 4                                                  ['O']
# ...                                                  ...
# 71915  ['INTRODUCTION', 'Concept', 'Epidemiology of a...
# 71916                                    ['T', 'B', 'D']
# 71917                                           ['Body']
# 71918                                           ['Body']
# 71919                 ['Conflict of interest statement']
#
#                                                 sections missing_fields
# 0      ['in the above-mentioned article, published in...             []
# 1      ['the demand for chemical energy is projected ...             []
# 2      ['cardiomyopathies represent a collection of d...             []
# 3      ['results of a bivariate regression of oef0 ag...   ['abstract']
# 4                                                   ['']             []
# ...                                                  ...            ...
# 71915  ['the pharmacological management of asthma has...             []
# 71916  ['the most important factor that determined th...             []
# 71917  ['to the editor: the primary malaria control t...             []
# 71918  ['natural products provide an interesting and ...   ['abstract']
# 71919  ['the authors declare that the research was co...   ['abstract']
#
# [71920 rows x 8 columns]

# %%
df_test = df_test.rename(columns={
            "full_text": "article",
            "abstract": "abstract"
        })
df_test = df_test.dropna(subset=["article", "abstract"])
df_test = df_test[df_test["article"].str.strip().astype(bool)]
df_test = df_test[df_test["abstract"].str.strip().astype(bool)]
df_test["article"] = df_test["article"].astype(str)
df_test["abstract"] = df_test["abstract"].astype(str)
len(df_test)
# Out:
# 46309

# %%
import ast
df_test['section_names'] = df_test['section_names'].apply(ast.literal_eval)
df_test['section_names']
# Out:
# 0                                                   [Body]
# 1        [Introduction, Biofuel Feedstocks, Engineering...
# 2        [Introduction, From code to message, The sarco...
# 5        [DATA AVAILABILITY STATEMENT, CONFLICT OF INTE...
# 6        [1. Application of the Next-Generation Sequenc...
#                                ...
# 71910    [Background, Main body, Conclusion, Supplement...
# 71914                                               [Body]
# 71915    [INTRODUCTION, Concept, Epidemiology of asthma...
# 71916                                            [T, B, D]
# 71917                                               [Body]
# Name: section_names, Length: 46309, dtype: object

# %%
from itertools import chain
texts = list(chain.from_iterable(df_test["section_names"]))
texts
# Out:
# ['Body',
#  'Introduction',
#  'Biofuel Feedstocks',
#  'Engineering Plants To Enhance Cellulosic Biomass',
#  'Challenges In Bioethanol Production – From Pre-Treatment To Fermentation',
#  'Pre-treatments',
#  'Biological Pre-treatments',
#  'Chemical Pre-treatments',
#  'Physical Pre-treatments',
#  'Thermal Pre-treatments',
#  'Enzymatic Pre-treatment',
#  'Fermentation',
#  'Integration Of Multiple Technologies For Lignocellulose Conversion',
#  'Cellulosic Biofuel Conversion Methods And The Prospect Of Emerging Technologies',
#  'The Importance of Government Policies for a Successful Biofuels Industry',
#  'Future Directions',
#  'Author Contributions',
#  'Conflict of Interest Statement',
#  'Introduction',
#  'From code to message',
#  'The sarcomere',
#  'The thin filament regulators',
#  'Troponin I',
#  'Troponin T',
#  'Troponin C',
#  'Tropomyosin',
#  'Allosteric communication defines the hierarchy of functional and pathological states',
#  'Structural biology efforts and treatment in the sarcomere',
#  'Signaling in hypertrophic cardiomyopathy',
#  'Concluding remarks',
#  'Author contributions',
#  'Conflict of interest statement',
#  'DATA AVAILABILITY STATEMENT',
#  'CONFLICT OF INTEREST STATEMENT',
#  '1. Application of the Next-Generation Sequencing (NGS) Technology for Analysis of Antarctic Samples',
#  '1.1. Beginning of the Antarctic Environmental Biology',
#  '1.2. The Rise of Environmental Metagenomics',
#  '1.3. 16S Hypervariable Regions',
#  '1.4. Richness and Diversity Indices',
#  '2. Community Composition of the Antarctic Ecosystems',
#  '2.1. General Trends in Antarctic Microorganism Distribution and Diversity',
#  '2.2. Sources of Microbial Life',
#  '2.3. Terrestrial Communities',
#  '2.3.1. Relationship between Geography and Microorganism Communities in Antarctic Soils',
#  '2.3.2. Relationships between Edaphic Factors and Microorganism Communities in Antarctic Soils',
#  '2.3.3. Roles of Different Microorganism Groups in Antarctic Soils',
#  '2.3.4. Lithobiont (Rock) Communities',
#  '2.4. Inland and Glacial Water Communities',
#  '2.4.1. Lake Communities',
#  '2.4.2. Meltwater Pond Communities',
#  '2.4.3. Subglacial Water Communities',
#  '2.5. Marine Communities',
#  '2.6. Microbial Mat and Sediment Communities',
#  '2.6.1. Community Composition',
#  '2.6.2. Factors Impacting the Mat Communities',
#  '2.7. Cryoconite Hole, Glacial Ice, and Snow Communities',
#  '2.7.1. Cryoconite Hole Communities',
#  '2.7.2. Ice and Glacial Microbial Communities',
#  '2.7.3. Snow Microbial Communities',
#  '2.8. Airborne Microorganisms',
#  '2.9. Impact of Macro Flora and Fauna on Microbial Communities',
#  '2.9.1. Impact of Higher Plants',
#  '2.9.2. Impact of Big Animals',
#  '2.9.3. Impact of Small Animals',
#  '2.10. Endemism',
#  '2.11. Impacts of Climatic Changes and Global Warming on Antarctic Microbial Communities',
#  '3. Conclusions',
#  'Funding',
#  'Availability of data and materials',
#  'Authors’ contributions',
#  'Authors’ information',
#  'Competing interests',
#  'Consent for publication',
#  'Ethics approval and consent to participate',
#  'INTRODUCTION',
#  'CASE REPORT',
#  'DISCUSSION',
#  'Introduction',
#  'Methods',
#  'Study setting and population',
#  'Data elements and analysis',
#  'Results',
#  'Discussion',
#  'Strengths and limitations',
#  'Policy implications',
#  'Conclusions',
#  'Body',
#  'Introduction and background',
#  'Review',
#  'Conclusions',
#  'INTRODUCTION',
#  'SINGLE CELL RNA CHALLENGES',
#  'APPLICATIONS OF SINGLE CELL RNA SEQUENCING TO RESEARCH OF STEM CELLS',
#  'Identification of cell subpopulations',
#  'Analysis of rare cell types',
#  'Description of developmental trajectories and regulatory networks',
#  'PERSPECTIVES',
#  'Introduction',
#  'Case report',
#  'Discussion',
#  'Declaration of conflicting interest',
#  'Funding',
#  'Background',
#  'Methods',
#  'Results',
#  'Conclusion',
#  'Background',
#  'Methods',
#  'Participants',
#  'Data collection',
#  'Diet',
#  'Anthropometric data',
#  'Statistical analysis',
#  'Ethical aspects',
#  'Results',
#  'Discussion',
#  'Conclusion',
#  'Funding',
#  'Availability of data and materials',
#  'Authors’ contributions',
#  'Competing interests',
#  'Consent for publication',
#  'Ethics approval and consent to participate',
#  '1. Background',
#  '2. The Course of the ASF Epidemic',
#  '3. Control Measures',
#  '4. Discussion',
#  '5. Conclusions',
#  None,
#  'Acknowledgements',
#  '1. Case Presentation',
#  '2. Discussion',
#  '3. Conclusion',
#  'INTRODUCTION',
#  'CASE REPORT',
#  'Case 1',
#  'Case 2',
#  'DISCUSSION',
#  'ARTICLE HIGHLIGHTS',
#  'Clinical diagnosis',
#  'Differential diagnosis',
#  'Imaging diagnosis',
#  'Pathological diagnosis',
#  'Treatment',
#  'Related reports',
#  'Experiences and lessons',
#  'Editorial',
#  '1. Introduction',
#  '1.1. Cancer',
#  '1.2. Epigenetics',
#  '1.2.1. DNA Methylation',
#  '1.2.2. Histone Modifications',
#  '1.2.3. Non-Coding RNAs',
#  '2. Implication of Epigenetics in the Development of Cancer',
#  '2.1. microRNAs',
#  '2.2. piRNAs and siRNAs',
#  '2.3. Long Non-Coding RNAs',
#  '3. Oxidative Stress and Its Effect in the Epigenetic Machinery to Promote Cancer',
#  '3.1. Effect over DNA Methylation',
#  '3.2. Effect over Histone Modifications',
#  '3.3. Effect over Non-Coding RNAs',
#  '4. Chemotherapy-Induced Oxidative Stress: Epigenetics and Cisplatin Resistance',
#  '4.1. Cisplatin Resistance Mechanisms',
#  '4.2. DNA Methylation and Histone Modifications',
#  '4.3. microRNAs',
#  'miR-7/MAFG/ROS axis',
#  '4.4. Long Non-Coding RNA',
#  '5. Conclusions and Future Directions',
#  'Introduction',
#  'Case presentation',
#  'Discussion',
#  'Conclusions',
#  '1. Introduction',
#  '2. Gastroenteropancreatic Neuroendocrine Tumors',
#  '3. Biochemical Diagnosis of GEP-NET',
#  '4. The Endocrine Role of Adipose Tissue and Inflammation in Obesity',
#  '5. Inflammation in Carcinogenesis',
#  '5.1. Interleukin 6',
#  '5.2. Tumor Necrosis Factor Alpha',
#  '5.3. Interleukin 17',
#  '5.4. Tumor Necrosis Factor-Related Apoptosis-Inducing Ligand',
#  '5.5. Interleukin 10',
#  '5.6. Interleukin 12',
#  '5.7. Transforming Growth Factor β',
#  '6. Inflammatory Factors in GEP-NET',
#  '7. Obesity and Its Comorbidities and the Risk of GEP-NETs',
#  '8. Conclusions',
#  'Simple Summary',
#  'Abstract',
#  '1. Introduction',
#  '2. Brain',
#  '2.1. Focal Abnormal Signal Intensities: Neuroradiological Tips and Tricks',
#  '2.2. Volume, Structural and Functional Connectivity Changes: More Than Meet the Eye',
#  '2.3. Epileptogenic Lesions in NF1',
#  '2.4. Altered Cerebrospinal Fluid Dynamics: Obstructive Hydrocephalus Other Than Tumor-Related',
#  '2.5. CNS Vascular Manifestations of NF1',
#  '3. Skull and Orbit',
#  '3.1. Sutural Defects',
#  '3.2. Skull Bone Defects and Associated Dural Dysplasia',
#  '3.2.1. Sphenoid Wing Dysplasia',
#  '3.2.2. Imaging Manifestation of Orbital Involvement',
#  '3.2.3. Imaging Manifestation of Oral Involvement',
#  '3.3. Macrocephaly',
#  '4. Spine',
#  '4.1. Medullary UBOs: A Stumbling Block to Neuroimaging',
#  '4.2. Dural Ectasia, Meningocele and Spinal Deformity: An Etiopathological Continuum',
#  '4.3. Chiari Malformation and Syrinx',
#  '5. Conclusions',
#  'INTRODUCTION',
#  'METHODS',
#  'RESULTS',
#  'DISCUSSION',
#  'CONCLUSION',
#  'Introduction',
#  'Loss of p53 is associated with an EMT-like phenotype',
#  'p53 and cell interactions with the extracellular matrix',
#  'Loss of p53 activates Rho GTPases and their associated signaling pathways',
#  'Mutant p53 proteins drive an aggressive cancer phenotype by gain of function',
#  'Mutant p53 proteins and cell migration',
#  'Mechanisms of mutant p53’s gain of function',
#  'p63 is an effector of mutant p53',
#  'Downstream of p63 to drive invasion and metastasis',
#  'Mutant p53, p63, and growth factor receptor trafficking',
#  'Conclusions',
#  'Objectives',
#  'Methods',
#  'Results',
#  'Conclusion',
#  'Objectives',
#  'Results',
#  'Initial clinical course and diagnosis of SCID with a IL2RG frameshift mutation',
#  'Engraftment of maternal CD8',
#  'Immunological characteristics of maternal engrafted CD8',
#  'Course before and after HCT',
#  'Discussion',
#  'Methods',
#  'T‐cell receptor excision circles (TRECs)',
#  'Next‐generation sequencing (NGS) panel',
#  'Surface antibody staining for flow cytometry',
#  'Cell sorting',
#  'TCR repertoire analysis',
#  'HLA typing',
#  'Antigen stimulation and intracellular cytokine staining',
#  'Methanol fixation for analysis of phosphorylated STAT5',
#  'Author contribution',
#  'Conflict of interest',
#  'Supporting information',
#  'Introduction: Identification of the COVID-19 pandemic',
#  'Chloroquine and hydroxychloroquine',
#  'Remdesivir and other nucleoside analogues',
#  'Antibody-based therapy for COVID-19',
#  'Chinese herbal medicine for treating SARS-COV-2 infection',
#  'Other options for treating COVID-19',
#  'Antiviral mechanisms of therapeutic agents against SARS-CoV2',
#  'Prevention of binding of coronavirus proteins to human cell receptors and inhibition of viral self-assembly',
#  'Inhibition of the replication of coronavirus RNA by action on polymerases',
#  'Inhibition of synthesis of viral protein and the enzymes of the coronavirus',
#  'Ab-mediated antiviral mechanisms for blocking SARS-CoV-2 infection',
#  'Anti-inflammatory mechanism of drugs for inhibiting the pathogenesis of SARS-CoV-2',
#  'Conclusions and future perspectives',
#  'Funding',
#  'Availability of data and materials',
#  "Authors' contributions",
#  'Ethics approval and consent to participate',
#  'Patient consent for publication',
#  'Competing interests',
#  'Main text',
#  'Declaration of interests',
#  'Introduction:',
#  'Case presentation:',
#  'Conclusion:',
#  'Introduction',
#  'Case report',
#  'Discussion',
#  'Introduction',
#  'Case Report',
#  'Discussion',
#  'Introduction',
#  'Case Presentation',
#  'Clinical Discussion',
#  'Conclusion',
#  'Introduction and importance',
#  'Case Presentation',
#  'Clinical discussion',
#  'Conclusion',
#  'Source of funding',
#  'Research registration number',
#  'Provenance and peer review',
#  'Ethical approval',
#  'Please state any sources of funding for your research',
#  'Author contribution',
#  'Registration of research studies',
#  'Guarantor',
#  'Consent',
#  'Declaration of competing interest',
#  'Body',
#  'Background',
#  'Case presentation',
#  'Conclusion',
#  'Background',
#  'Case presentation',
#  'Discussion and conclusion',
#  'Introduction',
#  'Symposium presentations',
#  'Conclusions',
#  'INTRODUCTION',
#  'CASE REPORT',
#  'DISCUSSION',
#  'CONFLICT OF INTEREST STATEMENT',
#  'Background',
#  'Case presentation',
#  'Conclusion',
#  'Background',
#  'Case presentation',
#  'Discussion',
#  'Conclusion',
#  'Consent',
#  'Competing interests',
#  'Authors’ contributions',
#  'Introduction',
#  'Congenital hypothyroidism (CH)',
#  'Subclinical hypothyroidism (SH)',
#  'Treat or not to treat SH?',
#  'Shifted TSH and T4 levels',
#  'Autoimmune thyroid disorders',
#  'Autoimmune hypothyroidism',
#  'Autoimmune hyperthyroidism',
#  'Screening recommendations',
#  'Conclusion',
#  'Body',
#  'Body',
#  'Case Report',
#  'Discussion',
#  'Conclusion',
#  'Body',
#  '1. Introduction',
#  '1.1. Obesity',
#  '1.2. The Hypothalamus as the Master Regulator of Energy Balance',
#  '2. Sirtuins: Metabolic Sensors',
#  '2.1. Hypothalamic SIRT1 in the Control of Energy Balance',
#  '2.2. SIRT1 and Food Intake',
#  '2.3. SIRT1 in Hypothalamic Neurons',
#  '2.4. SIRT1 a Link between Metabolism and Reproduction',
#  '3. Hypothalamic SIRT6 in the Control of Energy Balance',
#  '4. Therapeutic Options',
#  '5. Conclusions and Remarks',
#  '⧉ Early life and education',
#  '⧉ Escape through the Iron Curtain',
#  '⧉ A new life in Sweden',
#  '⧉ Early steps with Gamma Knife Surgery (GKS)',
#  '⧉ Retired, but only halfway through his career',
#  '⧉ A final return to Europe',
#  '⧉ Conclusions',
#  'Conflict of interests',
#  '1. Introduction',
#  '2. Materials and Methods',
#  '2.1. Screen Printing Process',
#  '2.2. Sputtered Thin-Film Strain Gauge',
#  '2.3. Gravity Die Cast Embedding Process',
#  '3. Results',
#  '3.1. Sensor Sheet Characterization before Casting',
#  '3.2. Results after the Embedding Process',
#  '4. Discussion',
#  'Introduction',
#  'Results',
#  'Patient characteristics',
#  'Prevalence of cardiometabolic complications in the PETALE cohort',
#  'Predictors of cardiometabolic complications among cALL survivors',
#  'Comparison to control cohort',
#  'Discussion',
#  'Methods',
#  'Aims',
#  'PETALE Cohort',
#  'Comparison Cohort',
#  'Outcome measurements',
#  'Measurements of overweight, obesity and body mass index during treatments',
#  'Statistical analyses',
#  'Availability of data and materials',
#  'Ethics approval and consent to participate',
#  '1. Introduction',
#  '2. How Can Archaea Affect Human Health?',
#  '3. Methanogens in the Oral Cavity: What Is New?',
#  '4. Methanogens in the Human Gut System: What Is New?',
#  '5. An Update on ',
#  '6. Open Questions',
#  '7. Final Remarks',
#  'INTRODUCTION',
#  'PATHOPHYSIOLOGY OF COVID‐19',
#  'MECHANISM OF ACTION OF MOLNUPIRAVIR IN COVID‐19',
#  'CLINICAL CONSIDERATION, AND DRUG INTERACTIONS OF MOLNUPIRAVIR',
#  'MOLNUPIRAVIR IN COVID‐19; PUBLISHED STUDIES',
#  'MOLNUPIRAVIR IN COVID‐19; ONGOING CLINICAL TRIALS',
#  'LIMITATION',
#  'CONCLUSION',
#  'ETHICS APPROVAL STATEMENT',
#  'DISCLOSURE',
#  'AUTHOR CONTRIBUTIONS',
#  'DATA AVAILABILITY STATEMENT',
#  'Introduction',
#  'Material and Methods',
#  'Signal Model',
#  'Data Acquisition',
#  'Image Processing',
#  'Data Analysis',
#  'Scan-Rescan Repeatability',
#  'Statistical Power Analysis',
#  'Results',
#  'Scan-Rescan Repeatability',
#  'Statistical Power Analysis',
#  'Discussion',
#  'Conclusions',
#  'Supplementary Material',
#  'Introduction',
#  'Compensatory hypersecretion of insulin: influence of genetic variation',
#  'Body fat composition',
#  'Perivascular adipose tissue',
#  'The fatty pancreas: non-alcoholic fatty pancreas disease',
#  'Response to lifestyle intervention',
#  'The phenotype of non-response to exercise',
#  'Insulin action in the human brain: the phenotype of brain insulin resistance',
#  'Brain insulin sensitivity: cause or consequence of adipose tissue distribution?',
#  'Effects of gestational diabetes on fetal brain: does primary brain insulin resistance exist?',
#  'Brain insulin resistance: starting point for organ crosstalk defining prediabetic phenotypes?',
#  'Background',
#  'Case Presentation',
#  'Discussion',
#  'Data Availability Statement',
#  'Ethics Statement',
#  'Author Contributions',
#  'Conflict of Interest',
#  "Publisher's Note",
#  'Introduction',
#  'Case Report',
#  'Discussion',
#  'Conclusions',
#  'INTRODUCTION',
#  'METHODS',
#  'RESULTS AND DISCUSSION',
#  'Behavioral responses to predation risk',
#  'Movement and habitat selection',
#  'Vigilance and herding',
#  'Physiological responses to predation risk',
#  'Diet quality and nutrition',
#  'Fitness and physiology',
#  'Trophic cascades resulting from ungulate responses to predation risk',
#  'Predator removal',
#  'Predator addition',
#  'Ungulate exclusion',
#  'Manipulation of predation risk',
#  'Top‐down approaches',
#  'Bottom‐up approaches',
#  'CONCLUSIONS',
#  'ACKNOWLEDGEMENT',
#  'CONFLICT OF INTEREST',
#  'AUTHOR CONTRIBUTIONS',
#  'Supporting information',
#  'DATA AVAILABILITY STATEMENT',
#  'INTRODUCTION',
#  'CASE REPORT',
#  'DISCUSSION',
#  'Introduction',
#  'Evidence of Involvement of Male Reproductive Tract',
#  'Theories of Pathogenesis of COVID in Testis',
#  'Future Directions and Implications',
#  'Financial support and sponsorship',
#  'Conflicts of interest',
#  'Introduction',
#  'Competing interests',
#  'Abbreviations',
#  'Acknowledgements',
#  'Electronic supplementary material',
#  'Background',
#  'Need for standards',
#  'Implementation of a Hydrocarbon Resource Environmental package',
#  'Development process & research community',
#  'Conclusions',
#  'Additional file',
#  'Funding',
#  'Availability of data and material',
#  'Authors’ contributions',
#  'Competing interests',
#  'Consent for publication',
#  'Ethics approval and consent to participate',
#  'Body',
#  None,
#  'Abbreviations',
#  'Competing interests',
#  'Body',
#  'Method of Treatment',
#  'First Recurrence',
#  'Second Recurrence',
#  'Third Recurrence',
#  'Fourth Recurrence',
#  'Results',
#  'Discussion',
#  'Summary',
#  'INTRODUCTION',
#  'CASE REPORT 1',
#  'CASE REPORT 2',
#  'DISCUSSION',
#  'Body',
#  None,
#  'Abbreviations',
#  'Competing interests',
#  'Body',
#  'Background',
#  'Materials and methods',
#  'Patients with oncohematologic malignancies',
#  'Candida',
#  'Aspergillus',
#  'Other fungi',
#  'Patients without oncohematologic malignancies',
#  'Chronic granulomatous disease (CGD)',
#  'Candida',
#  'Aspergillus',
#  'Other fungi',
#  'Biliary tract diseases',
#  'Candida',
#  'Aspergillus',
#  'Other fungi',
#  'Neonates and children',
#  'Candida',
#  'Aspergillus',
#  'Other fungi',
#  'Liver transplantation',
#  'Candida',
#  'Aspergillus',
#  'Other fungi',
#  'HIV',
#  'Candida',
#  'Other fungi',
#  'Conclusion',
#  'Body',
#  'Introduction',
#  'BHMF-Based Polyesters',
#  'Synthesis of Other BHMF-Based Polymers',
#  'Degradability of Furanic Polyesters',
#  'Toxicity of BHMF',
#  'Conclusion',
#  'Future Perspectives',
#  'Background',
#  'The co-creation process for the Engage digital platform',
#  'Facilitators and challenges in co-creating a digital engagement platform',
#  'Conclusions',
#  'INTRODUCTION',
#  'CASE REPORT',
#  'Histopathological examination',
#  'DISCUSSION',
#  'CONCLUSION',
#  'Declaration of the patient consent',
#  'Financial support and sponsorship',
#  'Conflicts of interest',
#  'INTRODUCTION',
#  'CASE SUMMARY',
#  'Clinical presentation',
#  'Differential diagnosis, investigations, and treatment',
#  'Outcomes and follow‐up',
#  'DISCUSSION',
#  'CONCLUSION',
#  'AUTHOR CONTRIBUTIONS',
#  'CONFLICT OF INTEREST',
#  'ETHICAL APPROVAL',
#  'HUMAN AND ANIMAL RIGHTS',
#  'CONSENT',
#  'DATA AVAILABILITY STATEMENT',
#  'Body',
#  '1. Introduction',
#  '2. Materials and Methods',
#  '2.1. Participants',
#  '2.2. Procedures',
#  '2.3. Analysis',
#  '3. Results',
#  '3.1. Perceptions of Stress',
#  '3.2. Sources of Stress',
#  '3.3. Consequences of Stress',
#  '3.4. Health Behaviors',
#  '3.5. Additional Behaviors',
#  '3.6. Coping Strategies',
#  '3.7. Sources of Social Support and Types of Social Support',
#  '3.8. Community Insights',
#  '3.9. Program Recommendations',
#  '4. Discussion',
#  '5. Conclusions',
#  'Backgrounds',
#  'Material/Methods',
#  'Results',
#  'Conclusions',
#  'Background',
#  'Material and Methods',
#  'Patient and samples',
#  'Immunohistochemistry staining',
#  'Evaluation of GPR110 staining',
#  'RNA extraction and quantitative real-time polymerase chain reaction (qRT-PCR)',
#  'Proliferation, migration, and invasion assays',
#  'Statistical analysis',
#  'Results',
#  'The expression of GPR110 in human osteosarcoma tissues',
#  'Correlation between GPR110 expression and clinicopathologic characteristics of osteosarcoma patients',
#  'Relationship between the expression level of GPR110 and overall survival in osteosarcoma patients',
#  'Overexpression of GPR110 promotes proliferation, migration, and invasion capacity of osteosarcoma cell lines',
#  'Discussion',
#  'Conclusions',
#  'BACKGROUND',
#  'CASE SUMMARY',
#  'CONCLUSION',
#  'INTRODUCTION',
#  'CASE PRESENTATION',
#  'Chief complaints',
#  'History of present illness',
#  'History of past illness',
#  'Personal and family history',
#  'Physical examination',
#  'Laboratory examinations',
#  'Imaging examinations',
#  'FINAL DIAGNOSIS',
#  'TREATMENT',
#  'OUTCOME AND FOLLOW-UP',
#  'DISCUSSION',
#  'CONCLUSION',
#  'ACKNOWLEDGEMENTS',
#  'Introduction',
#  'Physiological aspects',
#  'Clinical aspects',
#  'Conclusions',
#  'Introduction',
#  'Materials and Methods',
#  'Ethics statement',
#  'Study population',
#  'MRI technique',
#  'Image processing and disease segmentation',
#  'Utility of WBDWI for estimating tumor burden and ADCs',
#  'Statistical consideration',
#  'Results',
#  'Discussion',
#  'Supporting Information',
#  'Introduction',
#  'Materials and Methods',
#  'Study Design',
#  'Study Subjects',
#  'Total Pancreatectomy, Islet Isolation and Transplantation',
#  'Clinical Assays',
#  'Extracellular Flux',
#  'Statistical Analysis',
#  'Results',
#  'Discussion',
#  'INTRODUCTION',
#  'CASE REPORT',
#  'DISCUSSION',
#  'Body',
#  'Purpose:',
#  'Rationale:',
#  'Difficulties:',
#  'Background:',
#  'Neutrinos:',
#  'Communications:',
#  'Conclusions:',
#  'Keywords',
#  'Introduction',
#  'Ethical considerations',
#  'Case presentation',
#  'Discussion',
#  'Competing interests',
#  'Authors’ contributions',
#  'Funding information',
#  'Disclaimer',
#  'Subjective and objective truths',
#  '‘Illusory’ figures and higher cognitive factors',
#  'The subjective nature of colour vision',
#  'Objective truths can be deceptive',
#  'Nodes and essential nodes in vision',
#  'Quantification of the experience of complex visual stimuli',
#  'The quantification of reward, pain, desire and hate',
#  'Introduction',
#  'Case description',
#  'Discussion',
#  'Conclusion',
#  'Background',
#  'Competency-Based Education',
#  'Physician-Scientist Competencies',
#  'Advantages of Competency-Guided Program Design',
#  'Future Directions',
#  'Refining Competencies',
#  'Assessment',
#  'Conclusions',
#  'Setting',
#  'Objectives',
#  'Methods',
#  'Results and Conclusions',
#  'Introduction',
#  'Methods',
#  'Design',
#  'Study setting and population',
#  'Assessing compliance to RNTCP management guidelines',
#  'Data collection and analysis',
#  'Ethics Approval',
#  'Results',
#  'Characteristics of the study population',
#  'Compliance to existing RNTCP guidelines',
#  'Successful linkage after discharge for continuing anti-TB treatment',
#  'Discussion',
#  'Introduction',
#  'The BLAa and Cortico-Basal Ganglia Neural Networks',
#  'BLAa and Hippocampal Networks',
#  'Constructing Neural Networks of the Mammalian Brain',
#  '1. Introduction',
#  '2. The C-TEAM Meeting',
#  '3. Summary of the Current Situation',
#  '4. Outcomes and Future Plans',
#  'Introduction',
#  'Case report presentation',
#  'Discussion',
#  'Conclusion',
#  'CRediT authorship contribution statement',
#  'Declaration of Competing Interest',
#  'Introduction',
#  'Case presentation',
#  'Discussion',
#  'Conclusions',
#  'Introduction',
#  'Chain Length Limitation and Upscalability Aspects of Discrete Synthetic Macromolecules',
#  'Applications of Discrete Synthetic Macromolecules in Material Science Context',
#  'Macromolecular Data Storage',
#  'Self‐Assembly of Discrete Synthetic Macromolecules',
#  'Self‐Assembly of Discrete Block Copolymers',
#  'Sequence‐Selective Assembly and Duplex Formation of Precision Oligomers',
#  'Foldamers Based on Uniform Macromolecules',
#  'Catalysis',
#  'Applications of Discrete Synthetic Macromolecules in life Science',
#  'Lectin Binding Behavior of Discrete Oligomers',
#  'Antibacterial Properties of Discrete Synthetic Macromolecules',
#  'Other Applications of Discrete Synthetic Macromolecules',
#  'Conclusion and Future Trends',
#  'Conflict of Interest',
#  'Introduction',
#  'Case presentation',
#  'Conclusions',
#  'Introduction',
#  'Case presentation',
#  'Discussion',
#  'Conclusions',
#  'Consent',
#  'Abbreviations',
#  'Competing interests',
#  'Authors’ contributions',
#  'Acknowledgements',
#  '1. Introduction',
#  '2. Recent Papers Regarding Pediatric Exercise',
#  '2.1. Role of Quadriceps Exercises in Child and Adolescent Population Affected by Patellar Instability',
#  'Highlight by Vito Pavone, Andrea Vescio, Gianluca Testa',
#  '2.2. Adaptations to Resistance Training in Youth: Does the Maturity Level Matter?',
#  'Highlight by Helmi Chaabene',
#  '2.3. Pediatric Exercise: Play Stronger! To Live Better and Longer',
#  'Highlight by Antonino Bianco',
#  'BACKGROUND',
#  'CASE SUMMARY',
#  'CONCLUSION',
#  'INTRODUCTION',
#  'CASE PRESENTATION',
#  'Chief complaints',
#  'History of present illness',
#  'History of past illness',
#  'Personal and family history',
#  'Physical examination upon admission',
#  'Laboratory examinations',
#  'FINAL DIAGNOSIS',
#  'TREATMENT',
#  'OUTCOME AND FOLLOW-UP',
#  'DISCUSSION',
#  'CONCLUSION',
#  'ACKNOWLEDGEMENTS',
#  'INTRODUCTION',
#  'MATERIALS AND METHODS',
#  'Study framework',
#  'Brief presentation of the collection zones and biological materials',
#  'METHODS',
#  'Peroxide value measurement',
#  'Determination of the moisture and the volatile matters content',
#  'Determination of the acid value',
#  'Determination of the soap traces',
#  'Statistical analysis',
#  'RESULTS AND DISCUSSION',
#  'Results',
#  'Mineral oil',
#  'Discussion',
#  'CONCLUSION',
#  'CONFLICT OF INTERESTS',
#  'DATA AVAILABILITY STATEMENT',
#  None,
#  'Growth and maintenance',
#  'Sexual forms and their importance',
#  'Box 1. ',
#  'Life cycle',
#  None,
#  'Why Choose ',
#  None,
#  'Epidermis: a model for extracellular matrix production, wound healing, and cell fusion',
#  'Muscles—controlling animal movement',
#  'The digestive system—a model for organogenesis and pathogenesis',
#  'The nervous system—small yet complex',
#  'Reproductive tissue—sex-specific anatomy',
#  'The ',
#  None,
#  'Brief History of ',
#  'The ',
#  'Rationale:',
#  'Patient concerns:',
#  'Diagnosis:',
#  'Interventions:',
#  'Outcomes:',
#  'Lessons:',
#  'Introduction',
#  'Case presentation',
#  'Discussion',
#  'Conclusions',
#  'Acknowledgment',
#  'Author contributions',
#  '1. Introduction',
#  '2. Conclusions and Future Prospects',
#  'Background',
#  'Methods',
#  'Results',
#  'Conclusion',
#  'Introduction',
#  'Materials and methods',
#  'Synthesis of adherence criteria',
#  'Feasibility determination',
#  'Exploratory EGDT adherence assessment at an institution',
#  'Results',
#  'Synthesis of adherence criteria',
#  'Feasibility determination',
#  'Exploratory EGDT adherence assessment at an institution',
#  'Discussion',
#  'Conclusions',
#  'Supporting information',
#  'Introduction',
#  'Case Report',
#  'Discussion',
#  'Disclosures',
#  'Case Report',
#  'Discussion',
#  'Introduction',
#  'Case presentation',
#  'Discussion',
#  'Conclusions',
#  'Introduction',
#  'Case presentation',
#  'Conclusion',
#  'Introduction',
#  'Case presentation',
#  'Discussion',
#  'Conclusion',
#  'Funding',
#  'CRediT authorship contribution statement',
#  'Declaration of competing interest',
#  'Acknowledgement',
#  '1. Introduction to the Codon-Pair Customization of Pathogens',
#  '2. User-Directed Modulation of the Host Immune Response: Beyond Knockout Strains',
#  '3. Conclusion',
#  'INTRODUCTION',
#  'BURDEN OF KIDNEY DISEASE',
#  'Risk factors for kidney disease',
#  'Acute kidney injury',
#  'HEALTH POLICIES AND FINANCING OF KIDNEY DISEASE CARE',
#  'ORGANIZATION AND STRUCTURES FOR KIDNEY DISEASE CARE',
#  'Renal replacement therapies',
#  'Workforce for kidney care',
#  'CONCLUSION',
#  'Introduction',
#  'Data collection',
#  'Search strategy and selection criteria',
#  'Pre-specified PRO concepts',
#  'Statistical analyses',
#  'Instrument completion',
#  'Missing data and sensitivity analysis',
#  'Clinical relevance',
#  'Findings',
#  'Trial characteristics',
#  'PRO concepts',
#  'Statistical methods',
#  'PRO population',
#  'Definition of baseline',
#  'Definition of instrument completion',
#  'Missing data and sensitivity analysis',
#  'Clinical thresholds',
#  'Discussion',
#  'Body',
#  'Background',
#  'Methods',
#  'Results',
#  'Conclusions',
#  'INTRODUCTION',
#  'MATERIALS AND METHODS',
#  'Patient population and data collection',
#  'Therapeutic schemes',
#  'Assessment of safety and toxicity',
#  'Statistical analysis',
#  'RESULTS',
#  'Patient characteristics',
#  'Treatment',
#  'Efficacy',
#  'Toxicity and safety',
#  'DISCUSSION',
#  'ETHICS STATEMENT',
#  'CONFLICT OF INTEREST',
#  'DATA AVAILABILITY STATEMENT',
#  '1. Introduction',
#  '2. Case Report',
#  '3. Discussion',
#  '4. Conclusion',
#  'Background: ',
#  'Case Description: ',
#  'Conclusion: ',
#  'INTRODUCTION',
#  'CASE DESCRIPTION',
#  'Case 1',
#  'Case 2',
#  'DISCUSSION',
#  'CONCLUSION',
#  'Declaration of patient consent',
#  'Financial support and sponsorship',
#  'Conflicts of interest',
#  'Disclaimer',
#  'Introduction',
#  'The Awareness for Public Health in the 19',
#  'The dawn of Medicine before the turn of the 20',
#  'The changing panorama of life expectancy and diseases in the 20',
#  'The Bio-Medical Disease Model and the Bio-Psycho-Social Disease Model',
#  'ICF and its Use in Daily Medical and Social Life',
#  'Summary and prospects',
#  'AUTHOR CONTRIBUTIONS',
#  'ROLE OF THE STUDY SPONSOR',
#  'Supporting information',
#  '1. Introduction',
#  '2. DNA Methylation',
#  '3. Histone Modifications',
#  '4. MicroRNA Alteration',
#  '5. Conclusion',
#  'Introduction',
#  'Methods',
#  'Results',
#  'Discussion',
#  'Introduction',
#  'Psychology and cybersecurity',
#  'Country profiles and cultural dimensions',
#  'Eye-tracking',
#  'Materials and methods',
#  'Methodology',
#  'Stimuli, materials, and apparatus',
#  'Procedure',
#  'Data handling',
#  'Analysis protocol',
#  'Results',
#  'Discussion',
#  'Future research',
#  'Data availability statement',
#  'Ethics statement',
#  'Author contributions',
#  'Conflict of interest',
#  'Publisher’s note',
#  '1. Introduction',
#  '2. Case Presentation',
#  '3. Discussion',
#  'Introduction',
#  'Case Reports',
#  'Case 1',
#  'Case 2',
#  'Case 3',
#  'Discussion',
#  'Conflict of Interest',
#  'Authorship',
#  '1. Introduction',
#  '2. Methods',
#  '2.1. Materials and Chemicals',
#  '2.2. Formulation of Ag NWs Inks',
#  '2.3. Characterization',
#  '3. Results and Discussion',
#  '4. Conclusions',
#  '1. Introduction',
#  '2. Materials and Methods',
#  '3. Discussion and Conclusion',
#  'Introduction',
#  'Background',
#  'News media and health sentiment analysis',
#  'Motivation',
#  'Applicability',
#  'Related work',
#  'Data',
#  'Data collection and cleaning',
#  'Data labeling',
#  'Unsupervised labeling approach',
#  'Manual labeling approach',
#  'Methods',
#  'Neural network architecture',
#  'Embedding layer',
#  'BiLSTM layer',
#  'Attention layer',
#  'SoftMax layer',
#  'Model setting',
#  'Comparison models',
#  'Dataset and hyper-parameter settings',
#  ...]

# %%
from sentence_transformers import SentenceTransformer, InputExample, losses
fine_tuned_bert_model = SentenceTransformer("../../../section_normalization/models/fine_tuned_sentence_bert_model_ContrastiveLoss_test_lower")

# %%
import torch
import torch.nn as nn

class Classifier(nn.Module):
    def __init__(self, embedding_dim, num_classes):
        super(Classifier, self).__init__()
        self.fc1 = nn.Linear(embedding_dim, 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x  

torch.serialization.add_safe_globals([Classifier])

# %%
import torch
import pickle

model = torch.load("../../../section_normalization/classsifer_model/classifier_model_lower_test.pth", weights_only=False)

model.eval()  
threshold = 0.4

def predict(model, new_embeddings):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # 自動選擇 GPU 或 CPU
    model.to(device)  # 將模型移到對應設備
    new_embeddings = torch.tensor(new_embeddings, dtype=torch.float32).to(device)  # 轉換為 tensor 並移到設備

    with torch.no_grad():  # 禁用梯度計算，加速推理
        outputs = model(new_embeddings)  # 模型輸出 logits
        probabilities = torch.softmax(outputs, dim=1)  # 轉為機率分佈
        
        predictions = torch.argmax(outputs, dim=1)  # 取得預測類別
        max_probs, max_indices = torch.max(probabilities, dim=1)  # 取得最大機率及其對應的類別索引
        predictions = torch.where(max_probs >= threshold, max_indices, torch.tensor(-1, device=outputs.device))


    return predictions.cpu().numpy()

# %%
label2id = {
     "methods" : 0,
     "background" : 1,
     "results" : 2,
     "conclusions" : 3, 
     "objective": 4,
    "none": -1
}
id2label = {v: k for k, v in label2id.items()}

# %%
predictions_all = []

for texts in df_test['section_names']:
    clean_texts = [text.lower() if text is not None else "" for text in texts]
    
    embeddings = fine_tuned_bert_model.encode(clean_texts)
    predictions_supervised = predict(model, new_embeddings=embeddings)
    
    row_predictions = []
    for raw_text, pred in zip(texts, predictions_supervised):
        if raw_text is None:
            row_predictions.append("none") 
        else:
            row_predictions.append(id2label[pred])
            
    predictions_all.append(row_predictions)

df_test['predicted_section_names'] = predictions_all
df_test
# Out:
#       article_id      pmid                                              title  \
# 0      PMC498926  26530308                                            Erratum
# 1      PMC516104  28018390  Emerging Technologies for the Production of Re...
# 2      PMC503397  27721798  Cardiac Troponin and Tropomyosin: Structural a...
# 5      PMC997282  36865013  Unmet needs in clinical trials in CKD: questio...
# 6      PMC922807  35743947  Microbial Community Composition of the Antarct...
# ...          ...       ...                                                ...
# 71910  PMC811586  33980313  Patient engagement in fertility research: benc...
# 71914  PMC721866  32400027  Immunological fortification at our barrier org...
# 71915  PMC746268  32130345  2020 Brazilian Thoracic Association recommenda...
# 71916  PMC875428  35082458          Change is Inevitable Progress is Optional
# 71917  PMC343773  22932762  Novel Vectors of Malaria Parasite in the Weste...
#
#                                                 abstract  \
# 0      <S> lopez de lapuente a, pinto-medel mj, astob...
# 1      <S> plant cell walls are composed predominantl...
# 2      <S> inherited myopathies affect both skeletal ...
# 5      <S> abstract\nmany advances have been made in ...
# 6      <S> antarctica represents a unique environment...
# ...                                                  ...
# 71910  <S> background\npatient and public involvement...
# 71914  <S> summary\n\nour barrier surfaces are fundam...
# 71915  <S> abstract\nthe pharmacological management o...
# 71916  <S> how to cite this article: peter j. change ...
# 71917  <S> the main method of malaria control is base...
#
#                                                  article  \
# 0      in the above-mentioned article, published in m...
# 1      the demand for chemical energy is projected to...
# 2      cardiomyopathies represent a collection of dis...
# 5      data sharing is not applicable to this article...
# 6      before the mid-1980s, microbiological taxonomy...
# ...                                                  ...
# 71910  patient and public involvement (ppi) in resear...
# 71914  the barriers of the human body represent our f...
# 71915  the pharmacological management of asthma has c...
# 71916  the most important factor that determined the ...
# 71917  to the editor: the primary malaria control tec...
#
#                                            section_names  \
# 0                                                 [Body]
# 1      [Introduction, Biofuel Feedstocks, Engineering...
# 2      [Introduction, From code to message, The sarco...
# 5      [DATA AVAILABILITY STATEMENT, CONFLICT OF INTE...
# 6      [1. Application of the Next-Generation Sequenc...
# ...                                                  ...
# 71910  [Background, Main body, Conclusion, Supplement...
# 71914                                             [Body]
# 71915  [INTRODUCTION, Concept, Epidemiology of asthma...
# 71916                                          [T, B, D]
# 71917                                             [Body]
#
#                                                 sections missing_fields  \
# 0      ['in the above-mentioned article, published in...             []
# 1      ['the demand for chemical energy is projected ...             []
# 2      ['cardiomyopathies represent a collection of d...             []
# 5      ['data sharing is not applicable to this artic...             []
# 6      ['before the mid-1980s, microbiological taxono...             []
# ...                                                  ...            ...
# 71910  ['patient and public involvement (ppi) in rese...             []
# 71914  ['the barriers of the human body represent our...             []
# 71915  ['the pharmacological management of asthma has...             []
# 71916  ['the most important factor that determined th...             []
# 71917  ['to the editor: the primary malaria control t...             []
#
#                                  predicted_section_names
# 0                                              [methods]
# 1      [background, methods, methods, objective, meth...
# 2      [background, conclusions, background, methods,...
# 5                                  [methods, background]
# 6      [conclusions, background, background, methods,...
# ...                                                  ...
# 71910  [background, methods, conclusions, background,...
# 71914                                          [methods]
# 71915  [background, objective, background, results, m...
# 71916                      [methods, objective, methods]
# 71917                                          [methods]
#
# [46309 rows x 9 columns]

# %%
df_test = df_test[['article_id', 'pmid', 'title', 'abstract', 'section_names', 'sections', 'predicted_section_names']]
df_test
# Out:
#       article_id      pmid                                              title  \
# 0      PMC498926  26530308                                            Erratum
# 1      PMC516104  28018390  Emerging Technologies for the Production of Re...
# 2      PMC503397  27721798  Cardiac Troponin and Tropomyosin: Structural a...
# 5      PMC997282  36865013  Unmet needs in clinical trials in CKD: questio...
# 6      PMC922807  35743947  Microbial Community Composition of the Antarct...
# ...          ...       ...                                                ...
# 71910  PMC811586  33980313  Patient engagement in fertility research: benc...
# 71914  PMC721866  32400027  Immunological fortification at our barrier org...
# 71915  PMC746268  32130345  2020 Brazilian Thoracic Association recommenda...
# 71916  PMC875428  35082458          Change is Inevitable Progress is Optional
# 71917  PMC343773  22932762  Novel Vectors of Malaria Parasite in the Weste...
#
#                                                 abstract  \
# 0      <S> lopez de lapuente a, pinto-medel mj, astob...
# 1      <S> plant cell walls are composed predominantl...
# 2      <S> inherited myopathies affect both skeletal ...
# 5      <S> abstract\nmany advances have been made in ...
# 6      <S> antarctica represents a unique environment...
# ...                                                  ...
# 71910  <S> background\npatient and public involvement...
# 71914  <S> summary\n\nour barrier surfaces are fundam...
# 71915  <S> abstract\nthe pharmacological management o...
# 71916  <S> how to cite this article: peter j. change ...
# 71917  <S> the main method of malaria control is base...
#
#                                            section_names  \
# 0                                                 [Body]
# 1      [Introduction, Biofuel Feedstocks, Engineering...
# 2      [Introduction, From code to message, The sarco...
# 5      [DATA AVAILABILITY STATEMENT, CONFLICT OF INTE...
# 6      [1. Application of the Next-Generation Sequenc...
# ...                                                  ...
# 71910  [Background, Main body, Conclusion, Supplement...
# 71914                                             [Body]
# 71915  [INTRODUCTION, Concept, Epidemiology of asthma...
# 71916                                          [T, B, D]
# 71917                                             [Body]
#
#                                                 sections  \
# 0      ['in the above-mentioned article, published in...
# 1      ['the demand for chemical energy is projected ...
# 2      ['cardiomyopathies represent a collection of d...
# 5      ['data sharing is not applicable to this artic...
# 6      ['before the mid-1980s, microbiological taxono...
# ...                                                  ...
# 71910  ['patient and public involvement (ppi) in rese...
# 71914  ['the barriers of the human body represent our...
# 71915  ['the pharmacological management of asthma has...
# 71916  ['the most important factor that determined th...
# 71917  ['to the editor: the primary malaria control t...
#
#                                  predicted_section_names
# 0                                              [methods]
# 1      [background, methods, methods, objective, meth...
# 2      [background, conclusions, background, methods,...
# 5                                  [methods, background]
# 6      [conclusions, background, background, methods,...
# ...                                                  ...
# 71910  [background, methods, conclusions, background,...
# 71914                                          [methods]
# 71915  [background, objective, background, results, m...
# 71916                      [methods, objective, methods]
# 71917                                          [methods]
#
# [46309 rows x 7 columns]

# %%
df_test.to_parquet("../dataset/all_articles5-v2_predicted_section_names_lower.parquet")

# %%
df_test
# Out:
#       article_id      pmid                                              title  \
# 0      PMC498926  26530308                                            Erratum
# 1      PMC516104  28018390  Emerging Technologies for the Production of Re...
# 2      PMC503397  27721798  Cardiac Troponin and Tropomyosin: Structural a...
# 5      PMC997282  36865013  Unmet needs in clinical trials in CKD: questio...
# 6      PMC922807  35743947  Microbial Community Composition of the Antarct...
# ...          ...       ...                                                ...
# 71910  PMC811586  33980313  Patient engagement in fertility research: benc...
# 71914  PMC721866  32400027  Immunological fortification at our barrier org...
# 71915  PMC746268  32130345  2020 Brazilian Thoracic Association recommenda...
# 71916  PMC875428  35082458          Change is Inevitable Progress is Optional
# 71917  PMC343773  22932762  Novel Vectors of Malaria Parasite in the Weste...
#
#                                                 abstract  \
# 0      <S> lopez de lapuente a, pinto-medel mj, astob...
# 1      <S> plant cell walls are composed predominantl...
# 2      <S> inherited myopathies affect both skeletal ...
# 5      <S> abstract\nmany advances have been made in ...
# 6      <S> antarctica represents a unique environment...
# ...                                                  ...
# 71910  <S> background\npatient and public involvement...
# 71914  <S> summary\n\nour barrier surfaces are fundam...
# 71915  <S> abstract\nthe pharmacological management o...
# 71916  <S> how to cite this article: peter j. change ...
# 71917  <S> the main method of malaria control is base...
#
#                                            section_names  \
# 0                                                 [Body]
# 1      [Introduction, Biofuel Feedstocks, Engineering...
# 2      [Introduction, From code to message, The sarco...
# 5      [DATA AVAILABILITY STATEMENT, CONFLICT OF INTE...
# 6      [1. Application of the Next-Generation Sequenc...
# ...                                                  ...
# 71910  [Background, Main body, Conclusion, Supplement...
# 71914                                             [Body]
# 71915  [INTRODUCTION, Concept, Epidemiology of asthma...
# 71916                                          [T, B, D]
# 71917                                             [Body]
#
#                                                 sections  \
# 0      ['in the above-mentioned article, published in...
# 1      ['the demand for chemical energy is projected ...
# 2      ['cardiomyopathies represent a collection of d...
# 5      ['data sharing is not applicable to this artic...
# 6      ['before the mid-1980s, microbiological taxono...
# ...                                                  ...
# 71910  ['patient and public involvement (ppi) in rese...
# 71914  ['the barriers of the human body represent our...
# 71915  ['the pharmacological management of asthma has...
# 71916  ['the most important factor that determined th...
# 71917  ['to the editor: the primary malaria control t...
#
#                                  predicted_section_names
# 0                                              [methods]
# 1      [background, methods, methods, objective, meth...
# 2      [background, conclusions, background, methods,...
# 5                                  [methods, background]
# 6      [conclusions, background, background, methods,...
# ...                                                  ...
# 71910  [background, methods, conclusions, background,...
# 71914                                          [methods]
# 71915  [background, objective, background, results, m...
# 71916                      [methods, objective, methods]
# 71917                                          [methods]
#
# [46309 rows x 7 columns]
