# %%
import os
from datasets import load_dataset

ds = load_dataset("ccdv/pubmed-summarization", "document", cache_dir="./my_local_cache")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from datasets import load_dataset
#       4 ds = load_dataset("ccdv/pubmed-summarization", "document", cache_dir="./my_local_cache")
#
# File /ocean/projects/cis230089p/slin23/miniconda3/envs/gptoss20b/lib/python3.10/site-packages/datasets/__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "3.6.0"
# ---> 17 from .arrow_dataset import Dataset
#      18 from .arrow_reader import ReadInstruction
# ...

# %%
import pandas as pd


df = pd.read_json("dataset/pubmed-summarization-stream.jsonl", lines=True)
df
# Out:
#                                                 article  \
# 0     anxiety affects quality of life in those livin...
# 1     small non - coding rnas are transcribed into m...
# 2     ohss is a serious complication of ovulation in...
# 3     congenital adrenal hyperplasia ( cah ) refers ...
# 4     type 1 diabetes ( t1d ) results from the destr...
# ...                                                 ...
# 6653  neurocysticercosis is the most common parasiti...
# 6654  most chd prevalence data are based on populati...
# 6655  renal transplantation rates are low among pati...
# 6656  acute kidney injury ( aki ) , defined as an ab...
# 6657  human brain plasticity or neuroplasticity refe...
#
#                                                abstract background objective  \
# 0     research on the implications of anxiety in par...
# 1     small non - coding rnas include sirna , mirna ...
# 2     objective : to evaluate the efficacy and safet...
# ...

# %%
import pandas as pd


df = pd.read_json("dataset/classified_articles_stream.jsonl", lines=True)

# %%
df
# Out:
#      article_id      pmid                                              title  \
# 0     PMC696377  31842374  Plasmodesmata Conductivity Regulation: A Mecha...
# 1     PMC958938  36324544  Abderrazak Hajjioui: shining a light on rehabi...
# 2     PMC561342  28970690  Successful surgical procedure in a patient of ...
# 3     PMC642025  30875402  Assessment of early goal-directed therapy guid...
# 4     PMC579575  29172801  The new European guideline on cardiovascular d...
# ...         ...       ...                                                ...
# 4626  PMC883360  35158828  Alternative Splicing, Epigenetic Modifications...
# 4627  PMC424766  25403234  Let it grow—the open market solution to mariju...
# 4628  PMC766392  33167486  Gated Dehazing Network via Least Square Advers...
# 4629  PMC436037  21147631  Lung mass in a 28-year-old male: A case report...
# 4630   PMC42858  15157276
#
#                                                abstract  \
# ...

# %%
for i, row in df.iterrows():
    if row['article_id'] == 'PMC641128':
        print("background: ", row["background"])
        print("objective: ", row["objective"])
        print("methods: ", row["methods"])
        print("results: ", row["results"])
        print("conclusions: ", row["conclusions"])
        print("none: ", row["none"])
        break
# Out:
# background:  diabetes mellitus is a major source of morbidity in the united states (u.s.), the incidence of diabetes has increased markedly over time , tracking closely with increasing rates of adiposity , decreasing amounts of physical activity , and aging of the population. given the substantial incidence rates of both diabetes and prostate cancer, any relation of diabetes to the risk or severity of prostate cancer would have significant public health relevance. we examined the association between history of diabetes and prostate cancer risk in the prostate, lung, colorectal, and ovarian (plco) cancer study. we sought to examine this relationship stratified according to body mass and physical activity, variables closely related to glucose metabolism. a further goal was to investigate whether the association between diabetes and prostate cancer varied by psa level; the availability of comprehensive, prospective information on psa concentration allowed us to assess the influence of p
# ...

# %%
for i, row in df.iterrows():
    if row['article_id'] == 'PMC530944':
        print(row["full_text"])
        print(row["sections"])
        print(row["pmid"])
        break
# Out:
# the a5 segment aneurysms of the anterior cerebral artery are rare, approximately 0.5% of all intracranial aneurysms. they are small with a wide base located in the midline, with the domes mostly projecting upward or backward. the authors describe a unique case of a5 segment aneurysm, with the dome embedded into the body of the corpus callosum. this 41-year-old female was admitted to the neurology department for possible multiple sclerosis investigation. computed tomography angiogram (cta) revealed a 4-mm right-sided pericallosal artery aneurysm, with rare configuration, which was caudally projected, embedded into the body of the corpus callosum. the postoperative ct and cta showed no complication and successful occlusion of the aneurysm with no ischemia or hemorrhage in the corpus callosum. to the best of our knowledge, this is the first case of an aneurysm with this configuration. our rare case of a5 segment aneurysm demonstrates the importance of planning of the surgery, choosing t
# ...

# %%
for i, row in df.iterrows():
    if row['article_id'] == 'PMC867248':
        print(row["full_text"])
        print(row["sections"])
        print(row["pmid"])
        break
# Out:
# we are delighted to announce the 2020 recipients of the ming k. jeang award for excellence in cell & bioscience. three research groups, who each published an outstanding research article in cell & bioscience in 2020 [1–3], have been selected to receive this prestigious award by a panel of editors, chaired by dr. the ming k. jeang awards for excellence in cell & bioscience was established in 2011 with a generous endowment from the ming k. jeang foundation to honor outstanding research articles published in cell & bioscience, the society journal of the society for chinese bioscientists in america (scba), a non-profit scientific society, based in north america, https://scbasociety.org/. the selected articles are listed as below. senolytic compounds control a distinct fate of androgen receptor agonist and antagonist‑induced cellular senescent lncap prostate cancer cells. thanakorn pungsrinont, malika franziska sutter, maren c. c. m. ertingshausen, gopinath lakshmana, miriam kokal, amir s
# ...

# %%
for i, row in df.iterrows():
    if row['article_id'] == 'PMC867248':
        print(row["full_text"])
        print(row["sections"])
        print(row["pmid"])
        break

# %%
for i, row in df.iterrows():
    if row['article_id'] == 'PMC662519':
        print(row["full_text"])
        print(row["sections"])
        print(row["pmid"])
        break
# Out:
# the term transcriptome encompasses the complete set of rna molecules applying to an entire organism or specific cell type, making it more dynamic than the genome. two major classes of regulatory non-coding rnas (ncrnas) which lack any transcriptive capability include micrornas and long non-coding rnass (lncrnas). they play a significant role in diverse cellular processes from enabling normal development to disease progression, as well as cell communication. a valuable example of a biological carrier that can transport abundant quantities of lncrna is that of the exosome: a type of extracellular vesicle involved in cell-to-cell communication and disease transmission. its role has been documented in both physiological conditions and pathological changes such as cancer development, where they are responsible for the regulation of various processes including immunosuppression, proliferation and induction of pre-metastatic niche formation. in this review, the role of a number of exosomal 
# ...
