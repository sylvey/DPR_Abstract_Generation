# %%
import pandas as pd

df = pd.read_parquet('/jet/home/slin23/tmp_ondemand_ocean_cis230089p_symlink/slin23/full_text_label/section_normalization/for_section_normalization.parquet')
df
# Out:
#       article_id                                              title  \
# 0      PMC498926                                            Erratum
# 1      PMC516104  Emerging Technologies for the Production of Re...
# 2      PMC503397  Cardiac Troponin and Tropomyosin: Structural a...
# 3      PMC831342  Corrigendum: A Frequency-Domain Machine Learni...
# 4      PMC878323  Evolving Techniques in RSI: Can the Choice of ...
# ...          ...                                                ...
# 71916  PMC746268  2020 Brazilian Thoracic Association recommenda...
# 71917  PMC875428          Change is Inevitable Progress is Optional
# 71918  PMC343773  Novel Vectors of Malaria Parasite in the Weste...
# 71919  PMC986711         Natural Products for Cosmetic Applications
# 71920  PMC553242   Corrigendum: Dicer-Like Genes Are Required for H
#
#                                                 abstract  \
# 0      <S> lopez de lapuente a, pinto-medel mj, astob...
# ...

# %%
for i, row in df.iterrows():
    # if row['section_labels'] != []:
    print(row['section_labels'])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
type(df['sections'][0])
# Out:
# numpy.ndarray
